# %% [markdown]
# # The effect of synthetic data samples on timeseries classification task
#  In this task we will attempt to evaluate the effect of pre-training a model on synthetic data before training it for Electrocardiogram evaluation.
#   First we import needed python- libraries and read a csv file containing ECG recordings. All recordings are of V1 lead, and are a part of MIMIC-IV-ECG dataset provided by MIT. Since there is no free acess to SQL-database containing the diagnoses, the judgement call was based on amount of recordings inside one patients' folder. If the amount of recordings in a folder exceed 5, it was considered reasonable to assume that most of the recordings raised suspision with the nurse. Further evaluation following this article has confirmed noticeble difference between healthy and sick ECG-recordings.

# %%
# !pip install kagglehub
# !pip install tsgm
import os
os.environ["TF_USE_LEGACY_KERAS"] = "1"
import numpy as np
import tsgm
import tsgm.models.augmentations as augmentation
import tsgm.models.architectures as arch
import tsgm.models as models
import matplotlib.pyplot as plt
import csv
import tensorflow as tf
from tensorflow import keras
import sklearn 
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
import pandas as pd
import math
import kagglehub
# Out:
# Requirement already satisfied: kagglehub in /opt/software/lib/python3.10/site-packages (0.3.12)
# Requirement already satisfied: packaging in /opt/software/lib/python3.10/site-packages (from kagglehub) (23.2)
# Requirement already satisfied: pyyaml in /opt/software/lib/python3.10/site-packages (from kagglehub) (6.0.1)
# Requirement already satisfied: requests in /opt/software/lib/python3.10/site-packages (from kagglehub) (2.31.0)
# Requirement already satisfied: tqdm in /opt/software/lib/python3.10/site-packages (from kagglehub) (4.65.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/software/lib/python3.10/site-packages (from requests->kagglehub) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/software/lib/python3.10/site-packages (from requests->kagglehub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/software/lib/python3.10/site-packages (from requests->kagglehub) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/software/lib/python3.10/site-packages (from requests->kagglehub) (2024.8.30)
# Requirement already satisfied: tsgm in /opt/software/lib/python3.10/site-packages (0.0.7)
# Requirement already satisfied: scipy in /opt/software/lib/python3.10/site-packages (from tsgm) (1.11.3)
# Requirement already satisfied: numpy in /opt/software/lib/python3.10/site-packages (from tsgm) (1.23.5)
# Requirement already satisfied: networkx in /opt/software/lib/python3.10/site-packages (from tsgm) (3.2.1)
# Requirement already satisfied: seaborn in /opt/software/lib/python3.10/site-packages (from tsgm) (0.13.0)
# Requirement already satisfied: scikit-learn in /opt/software/lib/python3.10/site-packages (from tsgm) (1.3.2)
# Requirement already satisfied: prettytable in /opt/software/lib/python3.10/site-packages (from tsgm) (3.16.0)
# Requirement already satisfied: antropy==0.1.6 in /opt/software/lib/python3.10/site-packages (from tsgm) (0.1.6)
# Requirement already satisfied: yfinance==0.2.28 in /opt/software/lib/python3.10/site-packages (from tsgm) (0.2.28)
# Requirement already satisfied: tqdm in /opt/software/lib/python3.10/site-packages (from tsgm) (4.65.0)
# Requirement already satisfied: dtaidistance>=2.3.10 in /opt/software/lib/python3.10/site-packages (from tsgm) (2.3.13)
# Requirement already satisfied: tensorflow<2.16 in /opt/software/lib/python3.10/site-packages (from tsgm) (2.14.0)
# Requirement already satisfied: tensorflow-probability<0.24.0 in /opt/software/lib/python3.10/site-packages (from tsgm) (0.22.1)
# Requirement already satisfied: statsmodels in /opt/software/lib/python3.10/site-packages (from tsgm) (0.14.0)
# Requirement already satisfied: numba>=0.57 in /opt/software/lib/python3.10/site-packages (from antropy==0.1.6->tsgm) (0.58.1)
# Requirement already satisfied: stochastic in /opt/software/lib/python3.10/site-packages (from antropy==0.1.6->tsgm) (0.7.0)
# Requirement already satisfied: pandas>=1.3.0 in /opt/software/lib/python3.10/site-packages (from yfinance==0.2.28->tsgm) (2.2.3)
# Requirement already satisfied: requests>=2.31 in /opt/software/lib/python3.10/site-packages (from yfinance==0.2.28->tsgm) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/software/lib/python3.10/site-packages (from yfinance==0.2.28->tsgm) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /opt/software/lib/python3.10/site-packages (from yfinance==0.2.28->tsgm) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in /opt/software/lib/python3.10/site-packages (from yfinance==0.2.28->tsgm) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /opt/software/lib/python3.10/site-packages (from yfinance==0.2.28->tsgm) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/software/lib/python3.10/site-packages (from yfinance==0.2.28->tsgm) (2.4.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/software/lib/python3.10/site-packages (from yfinance==0.2.28->tsgm) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in /opt/software/lib/python3.10/site-packages (from yfinance==0.2.28->tsgm) (1.1)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/software/lib/python3.10/site-packages (from tensorflow<2.16->tsgm) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/software/lib/python3.10/site-packages (from tensorflow<2.16->tsgm) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/software/lib/python3.10/site-packages (from tensorflow<2.16->tsgm) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/software/lib/python3.10/site-packages (from tensorflow<2.16->tsgm) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/software/lib/python3.10/site-packages (from tensorflow<2.16->tsgm) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/software/lib/python3.10/site-packages (from tensorflow<2.16->tsgm) (3.10.0)
# Requirement already satisfied: ml-dtypes==0.2.0 in /opt/software/lib/python3.10/site-packages (from tensorflow<2.16->tsgm) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/software/lib/python3.10/site-packages (from tensorflow<2.16->tsgm) (3.3.0)
# Requirement already satisfied: packaging in /opt/software/lib/python3.10/site-packages (from tensorflow<2.16->tsgm) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/software/lib/python3.10/site-packages (from tensorflow<2.16->tsgm) (4.21.12)
# Requirement already satisfied: setuptools in /opt/software/lib/python3.10/site-packages (from tensorflow<2.16->tsgm) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in /opt/software/lib/python3.10/site-packages (from tensorflow<2.16->tsgm) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/software/lib/python3.10/site-packages (from tensorflow<2.16->tsgm) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/software/lib/python3.10/site-packages (from tensorflow<2.16->tsgm) (4.8.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /opt/software/lib/python3.10/site-packages (from tensorflow<2.16->tsgm) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/software/lib/python3.10/site-packages (from tensorflow<2.16->tsgm) (1.54.3)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /opt/software/lib/python3.10/site-packages (from tensorflow<2.16->tsgm) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /opt/software/lib/python3.10/site-packages (from tensorflow<2.16->tsgm) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /opt/software/lib/python3.10/site-packages (from tensorflow<2.16->tsgm) (2.14.0)
# Requirement already satisfied: decorator in /opt/software/lib/python3.10/site-packages (from tensorflow-probability<0.24.0->tsgm) (5.1.1)
# Requirement already satisfied: cloudpickle>=1.3 in /opt/software/lib/python3.10/site-packages (from tensorflow-probability<0.24.0->tsgm) (3.0.0)
# Requirement already satisfied: dm-tree in /opt/software/lib/python3.10/site-packages (from tensorflow-probability<0.24.0->tsgm) (0.1.7)
# Requirement already satisfied: wcwidth in /opt/software/lib/python3.10/site-packages (from prettytable->tsgm) (0.2.12)
# Requirement already satisfied: joblib>=1.1.1 in /opt/software/lib/python3.10/site-packages (from scikit-learn->tsgm) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/software/lib/python3.10/site-packages (from scikit-learn->tsgm) (3.2.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in /opt/software/lib/python3.10/site-packages (from seaborn->tsgm) (3.8.2)
# Requirement already satisfied: patsy>=0.5.2 in /opt/software/lib/python3.10/site-packages (from statsmodels->tsgm) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/software/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow<2.16->tsgm) (0.40.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/software/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance==0.2.28->tsgm) (2.5)
# Requirement already satisfied: webencodings in /opt/software/lib/python3.10/site-packages (from html5lib>=1.1->yfinance==0.2.28->tsgm) (0.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/software/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->tsgm) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/software/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->tsgm) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/software/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->tsgm) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/software/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->tsgm) (1.4.5)
# Requirement already satisfied: pillow>=8 in /opt/software/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->tsgm) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/software/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->tsgm) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/software/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->tsgm) (2.8.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /opt/software/lib/python3.10/site-packages (from numba>=0.57->antropy==0.1.6->tsgm) (0.41.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/software/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance==0.2.28->tsgm) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/software/lib/python3.10/site-packages (from requests>=2.31->yfinance==0.2.28->tsgm) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/software/lib/python3.10/site-packages (from requests>=2.31->yfinance==0.2.28->tsgm) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/software/lib/python3.10/site-packages (from requests>=2.31->yfinance==0.2.28->tsgm) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/software/lib/python3.10/site-packages (from requests>=2.31->yfinance==0.2.28->tsgm) (2024.8.30)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/software/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow<2.16->tsgm) (2.23.4)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /opt/software/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow<2.16->tsgm) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/software/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow<2.16->tsgm) (3.5.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/software/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow<2.16->tsgm) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/software/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow<2.16->tsgm) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/software/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow<2.16->tsgm) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/software/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow<2.16->tsgm) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/software/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow<2.16->tsgm) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/software/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow<2.16->tsgm) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/software/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow<2.16->tsgm) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/software/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow<2.16->tsgm) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/software/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow<2.16->tsgm) (3.2.2)
# 2025-06-23 15:35:31.559960: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-23 15:35:31.592391: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
seq_length = 250
num_classes = 2
tr_stages = 2 + 1   #Amount +1, since printing start at 1
epochs = 50
batch_size = 13

# %%
filtered_data = {}
treatment_data = {}

path = kagglehub.dataset_download("kirilltervoridor/mimic-iv-ecg-dataset")
with open(path + "/ECG_dataset.csv", "r") as ECG_ds:
    fieldnames = ["Healthy", "Treated"]
    reader = csv.DictReader(ECG_ds,fieldnames=fieldnames)
    i = 1
    for row in reader:
        filtered = row["Healthy"].replace("[","")
        filtered = filtered.replace("]","")
        treated = row["Treated"].replace("[","")
        treated = treated.replace("]","")
        if filtered != "":
            filtered_data.setdefault(int(i),float(2))
            filtered_data[int(i)] = list(filtered.split(","))
        
        treatment_data.setdefault(int(i),float(2))
        treatment_data[int(i)] = list(treated.split(","))
        
        i += 1

# %% [markdown]
# ## Ancillary functions
#  Theese are functions, that needed definition during experementing stage and were further used to keep the code clean. Most of them are described with a name and complete certain data manipulations.

# %%
def get_started(aug_meth, data):
    inst = np.shape(data)[0]
    time = np.linspace(0,10,seq_length)
    x_data = np.repeat([time],inst, axis=0)
    x_data = np.expand_dims(x_data,axis=-1).astype(np.float32)
    data = data.astype(np.float32)
    if aug_meth == "WindowWraping":
        aug_model = augmentation.WindowWarping()
        aug_x = aug_model.generate(X=np.expand_dims(data,-1), n_samples=data.shape[0], scales=(0.5,1), window_ratio=0.4)
        dataset = tf.constant(aug_x,dtype=tf.float32)
    elif aug_meth == "Shuffle":
        aug_model = augmentation.Shuffle()
        aug_x = aug_model.generate(X=np.expand_dims(data,-1), n_samples=data.shape[0])
        dataset= tf.constant(aug_x,dtype=tf.float32)
    elif aug_meth == "GaussianNoise":
        aug_model = augmentation.GaussianNoise()
        aug_x = aug_model.generate(X=np.expand_dims(data,-1), n_samples=data.shape[0],mean=0.03,variance=0.008)
        dataset = tf.constant(aug_x,dtype=tf.float32)
    else:
        dataset = tf.constant(data,dtype=tf.float32)
    x_data = tf.constant(x_data,dtype=tf.float32)
    dataset = tf.squeeze(dataset)

    
    return x_data, dataset

# %%
def gen_vector(n,data):
    inst = np.shape(data)[0]
    tmp_latent = tf.random.normal(shape=(n, seq_length, 1))
    vector_labels = tf.concat([tmp_latent, data[:n, :, None]], axis=2)
    
    return vector_labels, data

# %%
def generate_labels(filtered,treated):
    X_data = np.vstack((filtered,treated))
    X_data = X_data.reshape(np.shape(X_data)[0],np.shape(X_data)[1])
    healthy = np.zeros([len(filtered),1])
    sick = np.ones([len(treated),1])
    Y_data = np.vstack((healthy,sick))
    out = []
    for i in range (len(Y_data)):
        if Y_data[i] == 1:
            out.append([0,1])
        elif Y_data[i] == 0:
            out.append([1,0])
    return tf.constant(X_data,dtype=tf.float32), tf.constant(out,dtype=tf.float32)

# %%
def to_single(labels):
    rep = []
    for i in range(len(labels)):
        Res = max(labels[i])
        Res_i = list(labels[i]).index(Res)
        rep.append(Res_i)
    return rep

# %%
def compare(Result, true_labels):
    if len(Result) != len(true_labels):
        print("Sequence lengths did not match.")
        return None
    w = 0
    for i in range(len(Result)):
        Res = max(Result[i])
        Res_i = list(Result[i]).index(Res)
        if Res_i == list(true_labels[i]).index(1):
            w+=1
    return w/len(Result)

# %%
def distances(data):
    count=1
    ou = []
    out = []
    for item in data:
        for k in range(len(item)):
            if item[k] == 0:
                count += 1
            elif item[k] != 0:
                ou.append(count)
                count = 1
        if len(ou) > 3:
            while len(ou) < 30:
                ou.append(0)
            out.append(list(ou)[:30])
            ou.clear()
        else:
            ou.clear()
    return out

# %%
def modify_and_label(filtered,treated, cut=0.2):
    for item in filtered:
        for g in range(len(item)):
            if item[g] < cut:
                item[g] = 0
    for item in treated:
        for k in range(len(item)):
            if item[k] < cut:
                item[k] = 0
    filtered = distances(filtered)
    treated = distances(treated)
    X_data = []
    for item in filtered:
        X_data.append(item)
    for item in treated:
        X_data.append(item)
    healthy = np.zeros([len(filtered),1])
    sick = np.ones([len(treated),1])
    Y_data = np.vstack((healthy,sick))
    out = []
    for i in range (len(Y_data)):
        if Y_data[i] == 1:
            out.append([0,1])
        elif Y_data[i] == 0:
            out.append([1,0])
    return tf.constant(X_data,dtype=tf.float32), tf.constant(out,dtype=tf.float32)

# %%
def halve_data(data):
    dat_dic = {}
    out_dic = {}
    for key, value in data.items():
        dat, out = np.split(np.array(value,dtype=np.float32),2)
        dat_dic[key] = dat
        out_dic[key] = out
    return dat_dic, out_dic

# %%
def train_test_split(data, seq_length, current_length):
    prc = len(data) / 4
    tr = int(prc*2)
    tes = int(prc*3)
    splitter = current_length/seq_length
    train = np.zeros([tr-2,current_length])
    test = np.zeros([tes,current_length])


    for key, value in data.items():
        if key < tr-2:
            train[key-1] = np.array(data[key],dtype=np.float32)
        elif key >= tes:
            test[key-tes-1] = np.array(data[key],dtype=np.float32)
    
    train_s = np.zeros([tr-2,seq_length])
    test_s = np.zeros([tes,seq_length])
    tr_li = []
    tes_li = []
    for i in range(0,train.shape[0]):
        for j in range(0,train.shape[1]):
            if j % int(splitter) == 0:
                tr_li.append(train[i][j])
                tes_li.append(test[i][j])
        train_s[i] = np.array(tr_li, dtype=np.float32)
        test_s[i] = np.array(tes_li, dtype=np.float32)
        tr_li.clear()
        tes_li.clear()

    

    return(train_s,test_s)

filtered1, filtered0 = halve_data(filtered_data)
train_f1, test_f1  = train_test_split(data=filtered0, seq_length=seq_length, current_length=5000)
train_f2, test_f2 = train_test_split(data=filtered1, seq_length=seq_length, current_length=5000)
train_t,test_t = train_test_split(data=treatment_data, seq_length=seq_length, current_length=5000)
print(train_f1.shape)
print(train_f2.shape)
print(test_t.shape)
# Out:
# (135, 250)
# (135, 250)
# (288, 250)

# %% [markdown]
# # Synthetic data generation
#  To generate the data samples we will use TSGM-library and temporal version of Generative Aversarial model provided with it.

# %%
architecture = arch.zoo["t-cgan_c4"](seq_len=seq_length,feat_dim=1,latent_dim=1,output_dim=1)

# %%
GAN_Control = models.cgan.ConditionalGAN(discriminator=architecture.discriminator,generator=architecture.generator, latent_dim=1, temporal=True) 
GAN_Control.compile(d_optimizer=keras.optimizers.Adam(learning_rate=0.000017,epsilon=1e-9),g_optimizer=keras.optimizers.Adam(learning_rate=0.000113,epsilon=1e-8),loss_fn=keras.losses.BinaryCrossentropy())

# %%
x_data, dataset = get_started(aug_meth="",data=train_t)

datum = tf.data.Dataset.from_tensor_slices((x_data,dataset))
datum = datum.batch(5)

GAN_Control.fit(datum,epochs=3)
# Out:
# Epoch 1/3
# 38/38 [==============================] - 94s 2s/step - g_loss: 0.6929 - d_loss: 0.6351
# Epoch 2/3
# 38/38 [==============================] - 89s 2s/step - g_loss: 0.6932 - d_loss: 0.4732
# Epoch 3/3
# 38/38 [==============================] - 88s 2s/step - g_loss: 0.6945 - d_loss: 0.4029

# %%
generator_labels = tf.constant(np.ones([99,1]),dtype=tf.float32)

vector_labels, test_set = gen_vector(n=99,data=dataset)

Synthetic_data = GAN_Control.generate(vector_labels[:99,:,1])

# %%
tsgm.utils.visualize_ts_lineplot(Synthetic_data,test_set,3)

plt.show()

# %% [markdown]
# # Classification model definition
# For classification task we will define a LSTM-based Recurrent Neural Network. We will be training two models, first with synthetic data and other without. Both models will train for epochs x 1.5, where first one will start with epochs x 0.5 long synthetic training block and finish with epoch x 1 long ECG data training block. Model number two will have one epoch x 1.5 long training block on ECG data.

# %%
class Block(keras.layers.Layer):
    def __init__(self, input_dim, output_dim, **kwargs):
        super(Block, self).__init__(**kwargs)

        self.layer1 = keras.layers.Dense(units = input_dim*5)
        self.lstm = keras.layers.LSTM(units = output_dim,activation="sigmoid",recurrent_activation="sigmoid",unit_forget_bias=False,dropout=0.30)
        self.layer2 = keras.layers.Dense(units = input_dim*15)
        self.layer3 = keras.layers.Dense(units = input_dim*5)
        self.outlayer = keras.layers.Dense(units = output_dim)
        self.activ = keras.layers.ReLU()
        self.norm = keras.layers.BatchNormalization()
      
    def get_config(self):
        config = super.get_config()
        config.update(
            {
            "layer1": self.layer1,
            "lstm": self.lstm,
            "layer2": self.layer2,
            "layer3": self.layer3,
            "outlayer": self.outlayer,
            "activation": self.activ,
            "normalization": self.norm
            }
        )
        return config
    
    
    def call(self, x):
        y = self.layer1(x)
        y = self.activ(y)
        y = tf.expand_dims(y,axis=-1)
        y = self.lstm(y,training=True)
        #y = tf.squeeze(y)
        y = self.layer2(y)
        y = self.activ(y)
        y = self.layer3(y)
        y = self.activ(y)
        y = self.norm(y)
        out = self.outlayer(y)

        
        return out


class RNN(keras.Model):
    def __init__(self, input_dim, output_dim):
        super(RNN, self).__init__()
        
        self.layer1 = Block(input_dim, output_dim)
        self.layer2 = Block(input_dim, output_dim)
        self.layer3 = Block(input_dim, output_dim)

    def call(self, x):
        y = self.layer1(x)
        y = self.layer2(y)
        out = self.layer3(y)

        return out

# %%
Synthetic_data = tf.squeeze(Synthetic_data)

ind = np.arange(13,seq_length,13)
x_ex = np.zeros([99,seq_length])
for item in ind:
    for i in range(0,99):
        x_ex[i,item] = 0.27

# %%
Classif_model = RNN(seq_length, num_classes)
loss_Fn = keras.losses.CategoricalCrossentropy()

optimizer = keras.optimizers.Adam(learning_rate=0.05,
                                  beta_1=0.8,
                                  beta_2=0.999,
                                  epsilon=1e-7)

Classif_model.compile(optimizer=optimizer,
                      loss=loss_Fn,
                      metrics=["categorical_accuracy","F1Score"])

# %%
for stage in range(1,tr_stages):
    if stage == 1:
        x_train, y_train = modify_and_label(x_ex, 
                                            Synthetic_data.numpy(), 
                                            cut = 0.2
                                            )
        Classif_model.fit(x= x_train,
                         y= y_train,
                         batch_size= batch_size,
                         epochs=math.ceil(epochs/2),
                         shuffle=True
                         )
    else:
        x_train, y_train = modify_and_label(train_f1,
                                            train_t,
                                            cut = 0.2
                                           )
        Classif_model.fit(x= x_train,
                         y= y_train,
                         batch_size= batch_size,
                         epochs=epochs,
                         shuffle=True
                         )
# Out:
# Epoch 1/25
# 15/15 [==============================] - 46s 3s/step - loss: 8.9987 - categorical_accuracy: 0.5568 - f1_score: 0.5557
# Epoch 2/25
# 15/15 [==============================] - 41s 3s/step - loss: 8.7125 - categorical_accuracy: 0.5946 - f1_score: 0.5786
# Epoch 3/25
# 15/15 [==============================] - 41s 3s/step - loss: 8.6254 - categorical_accuracy: 0.5405 - f1_score: 0.5264
# Epoch 4/25
# 15/15 [==============================] - 41s 3s/step - loss: 8.7125 - categorical_accuracy: 0.5135 - f1_score: 0.4932
# Epoch 5/25
# 15/15 [==============================] - 42s 3s/step - loss: 8.6254 - categorical_accuracy: 0.5189 - f1_score: 0.5120
# Epoch 6/25
# 15/15 [==============================] - 42s 3s/step - loss: 8.6254 - categorical_accuracy: 0.4757 - f1_score: 0.4550
# Epoch 7/25
# 15/15 [==============================] - 42s 3s/step - loss: 8.6254 - categorical_accuracy: 0.4216 - f1_score: 0.4100
# Epoch 8/25
# 15/15 [==============================] - 43s 3s/step - loss: 8.6254 - categorical_accuracy: 0.4811 - f1_score: 0.4543
# Epoch 9/25
# 15/15 [==============================] - 42s 3s/step - loss: 8.6254 - categorical_accuracy: 0.5676 - f1_score: 0.5429
# Epoch 10/25
# 15/15 [==============================] - 40s 3s/step - loss: 8.6254 - categorical_accuracy: 0.5568 - f1_score: 0.5520
# Epoch 11/25
# 15/15 [==============================] - 41s 3s/step - loss: 7.5575 - categorical_accuracy: 0.5027 - f1_score: 0.4110
# Epoch 12/25
# 15/15 [==============================] - 37s 2s/step - loss: 1.9166 - categorical_accuracy: 0.5459 - f1_score: 0.5400
# Epoch 13/25
# 15/15 [==============================] - 41s 3s/step - loss: 0.7439 - categorical_accuracy: 0.5135 - f1_score: 0.5111
# Epoch 14/25
# 15/15 [==============================] - 42s 3s/step - loss: 0.8650 - categorical_accuracy: 0.5297 - f1_score: 0.5230
# Epoch 15/25
# 15/15 [==============================] - 41s 3s/step - loss: 0.8504 - categorical_accuracy: 0.4919 - f1_score: 0.4885
# Epoch 16/25
# 15/15 [==============================] - 41s 3s/step - loss: 0.7834 - categorical_accuracy: 0.4162 - f1_score: 0.4054
# Epoch 17/25
# 15/15 [==============================] - 40s 3s/step - loss: 0.8490 - categorical_accuracy: 0.4541 - f1_score: 0.4541
# Epoch 18/25
# 15/15 [==============================] - 43s 3s/step - loss: 0.7021 - categorical_accuracy: 0.5189 - f1_score: 0.5187
# Epoch 19/25
# 15/15 [==============================] - 41s 3s/step - loss: 0.7018 - categorical_accuracy: 0.5189 - f1_score: 0.5180
# Epoch 20/25
# 15/15 [==============================] - 40s 3s/step - loss: 0.6945 - categorical_accuracy: 0.4703 - f1_score: 0.4684
# Epoch 21/25
# 15/15 [==============================] - 42s 3s/step - loss: 0.6962 - categorical_accuracy: 0.4811 - f1_score: 0.4680
# Epoch 22/25
# 15/15 [==============================] - 40s 3s/step - loss: 0.6925 - categorical_accuracy: 0.5297 - f1_score: 0.5292
# Epoch 23/25
# 15/15 [==============================] - 42s 3s/step - loss: 0.6933 - categorical_accuracy: 0.4486 - f1_score: 0.4305
# Epoch 24/25
# 15/15 [==============================] - 40s 3s/step - loss: 0.6971 - categorical_accuracy: 0.5135 - f1_score: 0.5132
# Epoch 25/25
# 15/15 [==============================] - 42s 3s/step - loss: 0.6917 - categorical_accuracy: 0.4865 - f1_score: 0.4706
# Epoch 1/50
# 24/24 [==============================] - 68s 3s/step - loss: 0.6948 - categorical_accuracy: 0.5402 - f1_score: 0.5400
# Epoch 2/50
# 24/24 [==============================] - 69s 3s/step - loss: 0.6828 - categorical_accuracy: 0.4534 - f1_score: 0.4464
# Epoch 3/50
# 24/24 [==============================] - 65s 3s/step - loss: 0.6809 - categorical_accuracy: 0.4534 - f1_score: 0.4455
# Epoch 4/50
# 24/24 [==============================] - 65s 3s/step - loss: 0.6773 - categorical_accuracy: 0.3987 - f1_score: 0.3938
# Epoch 5/50
# 24/24 [==============================] - 65s 3s/step - loss: 0.6846 - categorical_accuracy: 0.4695 - f1_score: 0.4586
# Epoch 6/50
# 24/24 [==============================] - 64s 3s/step - loss: 0.6830 - categorical_accuracy: 0.4598 - f1_score: 0.4461
# Epoch 7/50
# 24/24 [==============================] - 65s 3s/step - loss: 0.6797 - categorical_accuracy: 0.4662 - f1_score: 0.4577
# Epoch 8/50
# 24/24 [==============================] - 63s 3s/step - loss: 0.6779 - categorical_accuracy: 0.4662 - f1_score: 0.4609
# Epoch 9/50
# 24/24 [==============================] - 63s 3s/step - loss: 0.6794 - categorical_accuracy: 0.4727 - f1_score: 0.4707
# Epoch 10/50
# 24/24 [==============================] - 68s 3s/step - loss: 0.6792 - categorical_accuracy: 0.4469 - f1_score: 0.4427
# Epoch 11/50
# 24/24 [==============================] - 68s 3s/step - loss: 0.6758 - categorical_accuracy: 0.4630 - f1_score: 0.4573
# Epoch 12/50
# 24/24 [==============================] - 65s 3s/step - loss: 0.6829 - categorical_accuracy: 0.4984 - f1_score: 0.4946
# Epoch 13/50
# 24/24 [==============================] - 65s 3s/step - loss: 0.6846 - categorical_accuracy: 0.4598 - f1_score: 0.4529
# Epoch 14/50
# 24/24 [==============================] - 66s 3s/step - loss: 0.6837 - categorical_accuracy: 0.4469 - f1_score: 0.4406
# Epoch 15/50
# 24/24 [==============================] - 66s 3s/step - loss: 0.6815 - categorical_accuracy: 0.4759 - f1_score: 0.4695
# Epoch 16/50
# 24/24 [==============================] - 65s 3s/step - loss: 0.6784 - categorical_accuracy: 0.5048 - f1_score: 0.4977
# Epoch 17/50
# 24/24 [==============================] - 65s 3s/step - loss: 0.7295 - categorical_accuracy: 0.4566 - f1_score: 0.4444
# Epoch 18/50
# 24/24 [==============================] - 67s 3s/step - loss: 0.7908 - categorical_accuracy: 0.4952 - f1_score: 0.4891
# Epoch 19/50
# 24/24 [==============================] - 66s 3s/step - loss: 0.8378 - categorical_accuracy: 0.5177 - f1_score: 0.5108
# Epoch 20/50
# 24/24 [==============================] - 62s 3s/step - loss: 1.1262 - categorical_accuracy: 0.4598 - f1_score: 0.4544
# Epoch 21/50
# 24/24 [==============================] - 67s 3s/step - loss: 0.6943 - categorical_accuracy: 0.4341 - f1_score: 0.3444
# Epoch 22/50
# 24/24 [==============================] - 67s 3s/step - loss: 0.7312 - categorical_accuracy: 0.5177 - f1_score: 0.5150
# Epoch 23/50
# 24/24 [==============================] - 70s 3s/step - loss: 0.7439 - categorical_accuracy: 0.4695 - f1_score: 0.4687
# Epoch 24/50
# 24/24 [==============================] - 62s 3s/step - loss: 0.7297 - categorical_accuracy: 0.5080 - f1_score: 0.4848
# Epoch 25/50
# 24/24 [==============================] - 60s 2s/step - loss: 0.6858 - categorical_accuracy: 0.5048 - f1_score: 0.4952
# Epoch 26/50
# 24/24 [==============================] - 61s 3s/step - loss: 0.7008 - categorical_accuracy: 0.5273 - f1_score: 0.5050
# Epoch 27/50
# 24/24 [==============================] - 64s 3s/step - loss: 0.6872 - categorical_accuracy: 0.5080 - f1_score: 0.4768
# Epoch 28/50
# 24/24 [==============================] - 60s 3s/step - loss: 0.6842 - categorical_accuracy: 0.4920 - f1_score: 0.4530
# Epoch 29/50
# 24/24 [==============================] - 63s 3s/step - loss: 0.6897 - categorical_accuracy: 0.5466 - f1_score: 0.5162
# Epoch 30/50
# 24/24 [==============================] - 66s 3s/step - loss: 0.6811 - categorical_accuracy: 0.5273 - f1_score: 0.4901
# Epoch 31/50
# 24/24 [==============================] - 68s 3s/step - loss: 0.6824 - categorical_accuracy: 0.5273 - f1_score: 0.4938
# Epoch 32/50
# 24/24 [==============================] - 65s 3s/step - loss: 0.6885 - categorical_accuracy: 0.4920 - f1_score: 0.4688
# Epoch 33/50
# 24/24 [==============================] - 66s 3s/step - loss: 0.6779 - categorical_accuracy: 0.5563 - f1_score: 0.5222
# Epoch 34/50
# 24/24 [==============================] - 69s 3s/step - loss: 0.6803 - categorical_accuracy: 0.5241 - f1_score: 0.4876
# Epoch 35/50
# 24/24 [==============================] - 67s 3s/step - loss: 0.6757 - categorical_accuracy: 0.5113 - f1_score: 0.4698
# Epoch 36/50
# 24/24 [==============================] - 66s 3s/step - loss: 0.6743 - categorical_accuracy: 0.4952 - f1_score: 0.4594
# Epoch 37/50
# 24/24 [==============================] - 66s 3s/step - loss: 0.6945 - categorical_accuracy: 0.5498 - f1_score: 0.5116
# Epoch 38/50
# 24/24 [==============================] - 64s 3s/step - loss: 0.6937 - categorical_accuracy: 0.5659 - f1_score: 0.5262
# Epoch 39/50
# 24/24 [==============================] - 60s 2s/step - loss: 0.6858 - categorical_accuracy: 0.5659 - f1_score: 0.5281
# Epoch 40/50
# 24/24 [==============================] - 65s 3s/step - loss: 0.6845 - categorical_accuracy: 0.5338 - f1_score: 0.5042
# Epoch 41/50
# 24/24 [==============================] - 66s 3s/step - loss: 0.6866 - categorical_accuracy: 0.5434 - f1_score: 0.5084
# Epoch 42/50
# 24/24 [==============================] - 68s 3s/step - loss: 0.6775 - categorical_accuracy: 0.5177 - f1_score: 0.4725
# Epoch 43/50
# 24/24 [==============================] - 65s 3s/step - loss: 0.6822 - categorical_accuracy: 0.5338 - f1_score: 0.5074
# Epoch 44/50
# 24/24 [==============================] - 66s 3s/step - loss: 0.6780 - categorical_accuracy: 0.5209 - f1_score: 0.4750
# Epoch 45/50
# 24/24 [==============================] - 66s 3s/step - loss: 0.6880 - categorical_accuracy: 0.5852 - f1_score: 0.5330
# Epoch 46/50
# 24/24 [==============================] - 67s 3s/step - loss: 0.6797 - categorical_accuracy: 0.5338 - f1_score: 0.4932
# Epoch 47/50
# 24/24 [==============================] - 65s 3s/step - loss: 0.6807 - categorical_accuracy: 0.5531 - f1_score: 0.5060
# Epoch 48/50
# 24/24 [==============================] - 64s 3s/step - loss: 0.6783 - categorical_accuracy: 0.5209 - f1_score: 0.4851
# Epoch 49/50
# 24/24 [==============================] - 67s 3s/step - loss: 0.6788 - categorical_accuracy: 0.5241 - f1_score: 0.4796
# Epoch 50/50
# 24/24 [==============================] - 67s 3s/step - loss: 0.6766 - categorical_accuracy: 0.4920 - f1_score: 0.4509

# %%
x_test, y_test =  modify_and_label(test_f1,
                                   test_t,
                                   cut = 0.2)

model_labels = Classif_model.predict(x_test)
# Out:
# 5/5 [==============================] - 3s 432ms/step

# %%
Classif_model2 = RNN(seq_length, num_classes)
loss_Fn = keras.losses.CategoricalCrossentropy()

optimizer = keras.optimizers.Adam(learning_rate=0.05,
                                  beta_1=0.8,
                                  beta_2=0.999,
                                  epsilon=1e-7)

Classif_model2.compile(optimizer=optimizer,
                      loss=loss_Fn,
                      metrics=["categorical_accuracy","F1Score"])

# %%
x_train, y_train = modify_and_label(train_f1,
                                    train_t,
                                    cut = 0.2
                                    )
Classif_model2.fit(x= x_train,
                  y= y_train,
                  batch_size= batch_size,
                  epochs=math.ceil(epochs*1.5),
                  shuffle=True
                 )
# Out:
# Epoch 1/75
# 24/24 [==============================] - 74s 3s/step - loss: 1.3237 - categorical_accuracy: 0.5402 - f1_score: 0.5323
# Epoch 2/75
# 24/24 [==============================] - 68s 3s/step - loss: 0.6920 - categorical_accuracy: 0.4920 - f1_score: 0.4908
# Epoch 3/75
# 24/24 [==============================] - 66s 3s/step - loss: 0.6841 - categorical_accuracy: 0.4630 - f1_score: 0.4510
# Epoch 4/75
# 24/24 [==============================] - 64s 3s/step - loss: 0.6914 - categorical_accuracy: 0.4341 - f1_score: 0.4260
# Epoch 5/75
# 24/24 [==============================] - 64s 3s/step - loss: 0.6824 - categorical_accuracy: 0.4566 - f1_score: 0.4384
# Epoch 6/75
# 24/24 [==============================] - 63s 3s/step - loss: 0.8410 - categorical_accuracy: 0.4502 - f1_score: 0.4258
# Epoch 7/75
# 24/24 [==============================] - 64s 3s/step - loss: 0.9144 - categorical_accuracy: 0.5756 - f1_score: 0.4938
# Epoch 8/75
# 24/24 [==============================] - 70s 3s/step - loss: 0.7002 - categorical_accuracy: 0.4887 - f1_score: 0.4773
# Epoch 9/75
# 24/24 [==============================] - 67s 3s/step - loss: 0.6839 - categorical_accuracy: 0.4727 - f1_score: 0.4556
# Epoch 10/75
# 24/24 [==============================] - 68s 3s/step - loss: 0.6789 - categorical_accuracy: 0.4277 - f1_score: 0.4078
# Epoch 11/75
# 24/24 [==============================] - 67s 3s/step - loss: 0.6796 - categorical_accuracy: 0.4309 - f1_score: 0.4104
# Epoch 12/75
# 24/24 [==============================] - 67s 3s/step - loss: 0.6778 - categorical_accuracy: 0.4244 - f1_score: 0.3899
# Epoch 13/75
# 24/24 [==============================] - 66s 3s/step - loss: 0.6801 - categorical_accuracy: 0.4695 - f1_score: 0.4503
# Epoch 14/75
# 24/24 [==============================] - 63s 3s/step - loss: 0.6791 - categorical_accuracy: 0.4277 - f1_score: 0.4048
# Epoch 15/75
# 24/24 [==============================] - 63s 3s/step - loss: 0.6789 - categorical_accuracy: 0.4180 - f1_score: 0.3831
# Epoch 16/75
# 24/24 [==============================] - 64s 3s/step - loss: 0.6795 - categorical_accuracy: 0.4469 - f1_score: 0.4277
# Epoch 17/75
# 24/24 [==============================] - 66s 3s/step - loss: 0.6774 - categorical_accuracy: 0.4309 - f1_score: 0.4170
# Epoch 18/75
# 24/24 [==============================] - 67s 3s/step - loss: 0.6767 - categorical_accuracy: 0.4148 - f1_score: 0.4081
# Epoch 19/75
# 24/24 [==============================] - 68s 3s/step - loss: 0.6800 - categorical_accuracy: 0.5145 - f1_score: 0.5099
# Epoch 20/75
# 24/24 [==============================] - 66s 3s/step - loss: 0.6790 - categorical_accuracy: 0.5048 - f1_score: 0.5011
# Epoch 21/75
# 24/24 [==============================] - 67s 3s/step - loss: 0.6804 - categorical_accuracy: 0.5305 - f1_score: 0.5295
# Epoch 22/75
# 24/24 [==============================] - 65s 3s/step - loss: 0.6776 - categorical_accuracy: 0.5209 - f1_score: 0.5170
# Epoch 23/75
# 24/24 [==============================] - 65s 3s/step - loss: 0.6763 - categorical_accuracy: 0.5498 - f1_score: 0.5434
# Epoch 24/75
# 24/24 [==============================] - 69s 3s/step - loss: 0.6783 - categorical_accuracy: 0.5531 - f1_score: 0.5476
# Epoch 25/75
# 24/24 [==============================] - 67s 3s/step - loss: 0.6807 - categorical_accuracy: 0.4855 - f1_score: 0.4832
# Epoch 26/75
# 24/24 [==============================] - 66s 3s/step - loss: 0.6745 - categorical_accuracy: 0.5852 - f1_score: 0.5742
# Epoch 27/75
# 24/24 [==============================] - 68s 3s/step - loss: 0.6765 - categorical_accuracy: 0.5273 - f1_score: 0.5229
# Epoch 28/75
# 24/24 [==============================] - 67s 3s/step - loss: 0.6832 - categorical_accuracy: 0.4920 - f1_score: 0.4869
# Epoch 29/75
# 24/24 [==============================] - 68s 3s/step - loss: 0.6815 - categorical_accuracy: 0.5241 - f1_score: 0.5157
# Epoch 30/75
# 24/24 [==============================] - 67s 3s/step - loss: 0.6840 - categorical_accuracy: 0.4566 - f1_score: 0.4533
# Epoch 31/75
# 24/24 [==============================] - 66s 3s/step - loss: 0.6790 - categorical_accuracy: 0.4791 - f1_score: 0.4732
# Epoch 32/75
# 24/24 [==============================] - 66s 3s/step - loss: 0.6816 - categorical_accuracy: 0.4695 - f1_score: 0.4657
# Epoch 33/75
# 24/24 [==============================] - 65s 3s/step - loss: 0.6806 - categorical_accuracy: 0.5370 - f1_score: 0.5335
# Epoch 34/75
# 24/24 [==============================] - 65s 3s/step - loss: 0.6795 - categorical_accuracy: 0.5113 - f1_score: 0.5057
# Epoch 35/75
# 24/24 [==============================] - 66s 3s/step - loss: 0.6815 - categorical_accuracy: 0.5466 - f1_score: 0.5405
# Epoch 36/75
# 24/24 [==============================] - 64s 3s/step - loss: 0.6834 - categorical_accuracy: 0.4662 - f1_score: 0.4609
# Epoch 37/75
# 24/24 [==============================] - 63s 3s/step - loss: 0.6784 - categorical_accuracy: 0.5177 - f1_score: 0.5115
# Epoch 38/75
# 24/24 [==============================] - 61s 3s/step - loss: 0.6836 - categorical_accuracy: 0.4984 - f1_score: 0.4920
# Epoch 39/75
# 24/24 [==============================] - 65s 3s/step - loss: 0.6797 - categorical_accuracy: 0.5145 - f1_score: 0.5099
# Epoch 40/75
# 24/24 [==============================] - 65s 3s/step - loss: 0.6790 - categorical_accuracy: 0.4855 - f1_score: 0.4816
# Epoch 41/75
# 24/24 [==============================] - 64s 3s/step - loss: 0.6790 - categorical_accuracy: 0.4695 - f1_score: 0.4630
# Epoch 42/75
# 24/24 [==============================] - 66s 3s/step - loss: 0.6804 - categorical_accuracy: 0.5241 - f1_score: 0.5199
# Epoch 43/75
# 24/24 [==============================] - 65s 3s/step - loss: 0.6784 - categorical_accuracy: 0.4373 - f1_score: 0.4288
# Epoch 44/75
# 24/24 [==============================] - 65s 3s/step - loss: 0.6812 - categorical_accuracy: 0.5273 - f1_score: 0.5264
# Epoch 45/75
# 24/24 [==============================] - 65s 3s/step - loss: 0.6800 - categorical_accuracy: 0.4887 - f1_score: 0.4857
# Epoch 46/75
# 24/24 [==============================] - 68s 3s/step - loss: 0.6800 - categorical_accuracy: 0.5273 - f1_score: 0.5209
# Epoch 47/75
# 24/24 [==============================] - 66s 3s/step - loss: 0.6800 - categorical_accuracy: 0.5595 - f1_score: 0.5436
# Epoch 48/75
# 24/24 [==============================] - 64s 3s/step - loss: 0.6800 - categorical_accuracy: 0.4630 - f1_score: 0.4510
# Epoch 49/75
# 24/24 [==============================] - 64s 3s/step - loss: 0.6799 - categorical_accuracy: 0.5145 - f1_score: 0.5054
# Epoch 50/75
# 24/24 [==============================] - 65s 3s/step - loss: 0.6802 - categorical_accuracy: 0.5016 - f1_score: 0.4923
# Epoch 51/75
# 24/24 [==============================] - 63s 3s/step - loss: 0.6779 - categorical_accuracy: 0.4759 - f1_score: 0.4652
# Epoch 52/75
# 24/24 [==============================] - 63s 3s/step - loss: 0.6813 - categorical_accuracy: 0.5048 - f1_score: 0.5026
# Epoch 53/75
# 24/24 [==============================] - 63s 3s/step - loss: 0.6800 - categorical_accuracy: 0.5338 - f1_score: 0.5233
# Epoch 54/75
# 24/24 [==============================] - 65s 3s/step - loss: 0.6799 - categorical_accuracy: 0.5145 - f1_score: 0.5099
# Epoch 55/75
# 24/24 [==============================] - 65s 3s/step - loss: 0.6794 - categorical_accuracy: 0.4405 - f1_score: 0.4325
# Epoch 56/75
# 24/24 [==============================] - 65s 3s/step - loss: 0.6804 - categorical_accuracy: 0.5627 - f1_score: 0.5564
# Epoch 57/75
# 24/24 [==============================] - 65s 3s/step - loss: 0.6788 - categorical_accuracy: 0.4502 - f1_score: 0.4457
# Epoch 58/75
# 24/24 [==============================] - 69s 3s/step - loss: 0.6758 - categorical_accuracy: 0.4469 - f1_score: 0.4399
# Epoch 59/75
# 24/24 [==============================] - 66s 3s/step - loss: 0.6781 - categorical_accuracy: 0.4791 - f1_score: 0.4739
# Epoch 60/75
# 24/24 [==============================] - 62s 3s/step - loss: 0.6833 - categorical_accuracy: 0.5145 - f1_score: 0.5046
# Epoch 61/75
# 24/24 [==============================] - 64s 3s/step - loss: 0.6814 - categorical_accuracy: 0.4823 - f1_score: 0.4753
# Epoch 62/75
# 24/24 [==============================] - 64s 3s/step - loss: 0.6800 - categorical_accuracy: 0.5016 - f1_score: 0.4963
# Epoch 63/75
# 24/24 [==============================] - 66s 3s/step - loss: 0.6808 - categorical_accuracy: 0.5080 - f1_score: 0.5006
# Epoch 64/75
# 24/24 [==============================] - 63s 3s/step - loss: 0.6791 - categorical_accuracy: 0.5241 - f1_score: 0.5180
# Epoch 65/75
# 24/24 [==============================] - 65s 3s/step - loss: 0.6793 - categorical_accuracy: 0.4952 - f1_score: 0.4867
# Epoch 66/75
# 24/24 [==============================] - 64s 3s/step - loss: 0.6790 - categorical_accuracy: 0.5305 - f1_score: 0.5196
# Epoch 67/75
# 24/24 [==============================] - 65s 3s/step - loss: 0.6797 - categorical_accuracy: 0.5273 - f1_score: 0.5209
# Epoch 68/75
# 24/24 [==============================] - 64s 3s/step - loss: 0.6770 - categorical_accuracy: 0.5305 - f1_score: 0.5238
# Epoch 69/75
# 24/24 [==============================] - 66s 3s/step - loss: 0.6838 - categorical_accuracy: 0.4791 - f1_score: 0.4583
# Epoch 70/75
# 24/24 [==============================] - 69s 3s/step - loss: 0.6819 - categorical_accuracy: 0.5273 - f1_score: 0.5245
# Epoch 71/75
# 24/24 [==============================] - 65s 3s/step - loss: 0.6781 - categorical_accuracy: 0.4630 - f1_score: 0.4616
# Epoch 72/75
# 24/24 [==============================] - 64s 3s/step - loss: 0.6810 - categorical_accuracy: 0.4695 - f1_score: 0.4489
# Epoch 73/75
# 24/24 [==============================] - 66s 3s/step - loss: 0.6787 - categorical_accuracy: 0.4148 - f1_score: 0.3929
# Epoch 74/75
# 24/24 [==============================] - 62s 3s/step - loss: 0.6804 - categorical_accuracy: 0.4630 - f1_score: 0.4308
# Epoch 75/75
# 24/24 [==============================] - 64s 3s/step - loss: 0.6814 - categorical_accuracy: 0.4727 - f1_score: 0.4614

# %%
x_test, y_test =  modify_and_label(test_f1,
                                   test_t,
                                   cut = 0.2)

model_labels2 = Classif_model2.predict(x_test)
# Out:
# 5/5 [==============================] - 2s 393ms/step

# %% [markdown]
# # Model comparison
# For comparison we will use accuracy score and F1-score.

# %%
y_examp = to_single(y_test)
model_y = to_single(model_labels)
Acc = accuracy_score(model_y,y_examp)
Con_MA = confusion_matrix(model_y,y_examp)
F1 = f1_score(model_y,y_examp)

# %%
y_examp2 = to_single(y_test)
model_y2 = to_single(model_labels2)
Acc2 = accuracy_score(model_y2,y_examp2)
Con_MA2 = confusion_matrix(model_y2,y_examp2)
F1_2 = f1_score(model_y2,y_examp2) 

print(f"Mixed model accuracy: {Acc:.2f} vs Regular model accuracy: {Acc2:.2f} \n")
print(f" Mixed model confusion matrix: \n{Con_MA} \nvs")
print(f" Regular model confusion matrix: \n{Con_MA2}")
print(f"\n Mixed model F1-score: {F1:.2f} vs Regular model F1-score: {F1_2:.2f}")
# Out:
# Mixed model accuracy: 0.54 vs Regular model accuracy: 0.50
#
#  Mixed model confusion matrix:
# [[24 29]
#  [43 61]]
# vs
#  Regular model confusion matrix:
# [[19 31]
#  [48 59]]
#
#  Mixed model F1-score: 0.63 vs Regular model F1-score: 0.60
